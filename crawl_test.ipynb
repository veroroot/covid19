# %%
import pickle
import re
import time
import pandas as pd
from selenium import webdriver
from bs4 import BeautifulSoup

# %%
url = 'http://ncov.mohw.go.kr/bdBoardList_Real.do?brdId=1&brdGubun=12&ncvContSeq=&contSeq=&board_id=&gubun='

pattern = re.compile(r'\s+')

# %%
driver = webdriver.Chrome('C:\chromedriver\chromedriver.exe')
driver.implicitly_wait(3)

driver.get(url)

# %%
number = []
information = []
inject_path = []
admit_date = []
hospital = []
contact = []
mov_paths_txt = []

for i in range(9, 0, -1) :
    time.sleep(3)
    driver.find_element_by_css_selector(f'#content > div > div.paging > a:nth-child({i})').click()
    time.sleep(3)
    driver.find_element_by_id('pson_moveAll_open').click()

    html = driver.page_source
    soup = BeautifulSoup(html, 'html.parser')

    persons = soup.select_one('#content > div > div.pson_move_list.mgt12 > div.in_list').find_all('div', {"class":"onelist open"})

    for person in persons :
        person_info = person.find_all("ul")[0].find_all('li')
        if len(person.find_all("ul")) == 1:
            mov_paths_txt.append('not yet')
        else :
            mov_path = person.find_all("ul")[1]
            mov_paths_txt.append(mov_path.text)
        
        num = person_info[0].find_all('span')[1].text
        info = person_info[1].find_all('span')[1].text
        path = person_info[2].find_all('span')[1].text
        date = person_info[3].find_all('span')[1].text
        date = re.sub(pattern, '', date) 
        hosptl = person_info[4].find_all('span')[1].text
        connect = person_info[5].find_all('span')[1].text
        connect = re.sub(pattern, '', connect)
        print('num : '+num+', info : '+info+', path : '+path+', date : '+date+', hosptl : '+hosptl+', conncect : '+connect)
                
        number.append(num)
        information.append(info)
        inject_path.append(path)
        admit_date.append(date)
        hospital.append(hosptl)
        contact.append(connect)
        print('person complete')
        print('='*50)
    print('page complete')
    print('='*100)

# 일단 정보 및 이동경로만 가져옴. 추후 인원에 따른 이동경로로 가져오고 데이터 전처리가 필요함(시간, 장소, 증상, 기타 등으로 텍스트 구분)

frame = {'환자' : number, '인적사항' : information, '감염경로' : inject_path, '확진일자' : admit_date, '입원기관' : hospital, '접촉자수' : contact, '이동경로' : mov_paths_txt}
covid19 = pd.DataFrame(frame)

covid19.to_csv("covid19.csv")
# Out:
# num : 2, info : 남 (한국, '64), path : 우한방문 (1차), date : 1.24, hosptl : 격리 해제, conncect : 75(0)
# person complete
# ==================================================
# num : 1, info : 여 (중국, '84), path : 우한방문 (1차), date : 1.20, hosptl : 격리 해제, conncect : 45(0)
# person complete
# ==================================================
# page complete
# ====================================================================================================
# num : 12, info : 남 (중국, '71), path : 일본 내 확진환자 접촉자 (2차), date : 2.1, hosptl : 분당서울대병원, conncect : 422(0)
# person complete
# ==================================================
# num : 11, info : 남 (한국, '95), path : 6번째 환자(3번째 환자 접촉자) 접촉자 (3차), date : 1.31, hosptl : 격리 해제, conncect : 0(0)
# person complete
# ==================================================
# num : 10, info : 여 (한국, '66), path : 6번째 환자(3번째 환자 접촉자) 접촉자 (3차), date : 1.31, hosptl : 서울대병원, conncect : 43(0)
# person complete
# ==================================================
# num : 9, info : 여 (한국, '92), path : 5번째 환자 접촉자 (2차), date : 1.31, hosptl : 격리 해제, conncect : 2(0)
# person complete
# ==================================================
# num : 8, info : 여 (한국, '57), path : 우한방문 (1차), date : 1.31, hosptl : 격리 해제, conncect : 113(0)
# person complete
# ==================================================
# num : 7, info : 남 (한국, '91), path : 우한방문 (1차), date : 1.30, hosptl : 격리 해제, conncect : 9(0)
# person complete
# ==================================================
# num : 6, info : 남 (한국, '64), path : 3번째 환자 접촉자 (2차), date : 1.30, hosptl : 서울대병원, conncect : 17(1)
# person complete
# ==================================================
# num : 5, info : 남 (한국, '87), path : 우한방문 (1차), date : 1.30, hosptl : 서울의료원, conncect : 31(0)
# person complete
# ==================================================
# num : 4, info : 남 (한국, '64), path : 우한방문 (1차), date : 1.27, hosptl : 격리 해제, conncect : 95(0)
# person complete
# ==================================================
# num : 3, info : 남 (한국, '66), path : 우한방문 (1차), date : 1.26, hosptl : 격리 해제, conncect : 16(0)
# person complete
# ==================================================
# page complete
# ====================================================================================================
# num : 22, info : 남 (한국, '73), path : 16번째 확진자의 가족 (2차), date : 2.6, hosptl : 격리 해제, conncect : 1(1)
# person complete
# ==================================================
# num : 21, info : 여 (한국, '60), path : 6번째 환자(3번째 환자 접촉자) 접촉자 (3차), date : 2.5, hosptl : 서울대병원, conncect : 6(1)
# person complete
# ==================================================
# num : 20, info : 여 (한국, '78), path : 15번째 확진자(4번째 확진자 접촉자)의 가족 (3차), date : 2.5, hosptl : 격리 해제, conncect : 2(0)
# person complete
# ==================================================
# num : 19, info : 남 (한국, '83), path : 싱가포르 컨퍼런스 내 확진자 접촉자 (2차), date : 2.5, hosptl : 격리 해제, conncect : 68(1)
# person complete
# ==================================================
# num : 18, info : 여 (한국, '99), path : 16번째 환자의 딸 (2차), date : 2.5, hosptl : 격리 해제, conncect : 8(0)
# person complete
# ==================================================
# num : 17, info : 남 (한국, '82), path : 싱가포르 컨퍼런스 내 확진자 접촉자 (2차), date : 2.5, hosptl : 격리 해제, conncect : 290(0)
# person complete
# ==================================================
# num : 16, info : 여 (한국, '77), path : 태국여행 (1차), date : 2.4, hosptl : 격리 해제, conncect : 450(64)
# person complete
# ==================================================
# num : 15, info : 남 (한국, '77), path : 4번째 확진자 접촉자(항공기) (2차), date : 2.2, hosptl : 격리 해제, conncect : 15(4)
# person complete
# ==================================================
# num : 14, info : 여 (중국, '80), path : 12번째 환자(일본 내 확진환자 접촉자) 가족 (3차), date : 2.2, hosptl : 분당서울대병원, conncect : 3(0)
# person complete
# ==================================================
# num : 13, info : 남 (한국, '92), path : 우한방문 (1차), date : 2.2, hosptl : 격리 해제, conncect : 0(0)
# person complete
# ==================================================
# page complete
# ====================================================================================================
# num : 32, info : 여 (한국, '09), path : 확인 중 (확인 중), date : 2.18, hosptl : 분당서울대병원, conncect : 확인중(확인중)
# person complete
# ==================================================
# num : 31, info : 여 (한국, '59), path : 확인 중 (확인 중), date : 2.18, hosptl : 대구의료원, conncect : 1160(1160)
# person complete
# ==================================================
# num : 30, info : 여 (한국, '52), path : 29번째 환자의 접촉자(배우자) (확인 중), date : 2.16, hosptl : 서울대학교병원, conncect : 27(27)
# person complete
# ==================================================
# num : 29, info : 남 (한국, '38), path : 확인 중 (확인 중), date : 2.16, hosptl : 서울대학교병원, conncect : 117(117)
# person complete
# ==================================================
# num : 28, info : 여 (중국, '89), path : 3번째 환자 접촉자 (2차), date : 2.10, hosptl : 격리 해제, conncect : 1(1)
# person complete
# ==================================================
# num : 27, info : 여 (중국, '82), path : 25번째 환자의 가족 (2차), date : 2.9, hosptl : 경기도의료원 안성병원, conncect : 40(0)
# person complete
# ==================================================
# num : 26, info : 남 (한국, '68), path : 25번째 환자의 가족 (2차), date : 2.9, hosptl : 경기도의료원 안성병원, conncect : 0(0)
# person complete
# ==================================================
# num : 25, info : 여 (한국, '46), path : 27번째 확진자 접촉자 (2차), date : 2.9, hosptl : 분당서울대병원, conncect : 12(11)
# person complete
# ==================================================
# num : 24, info : 남 (한국, '92), path : 우한방문 (1차), date : 2.6, hosptl : 국립중앙의료원, conncect : 0(0)
# person complete
# ==================================================
# num : 23, info : 여 (중국, '62), path : 우한방문 (1차), date : 2.6, hosptl : 국립중앙의료원, conncect : 23(7)
# person complete
# ==================================================
# page complete
# ====================================================================================================
# num : 42, info : 여 (한국, '91), path : 확인 중 (확인 중), date : 2.19, hosptl : 대구의료원, conncect : 확인중(확인중)
# person complete
# ==================================================
# num : 41, info : 여 (한국, '51), path : 확인 중 (확인 중), date : 2.19, hosptl : 동국대학교경주병원, conncect : 확인중(확인중)
# person complete
# ==================================================
# num : 40, info : 남 (한국, '43), path : 확인 중 (확인 중), date : 2.19, hosptl : 국립중앙의료원, conncect : 8(8)
# person complete
# ==================================================
# num : 39, info : 여 (한국, '59), path : 확인 중 (확인 중), date : 2.18, hosptl : 동국대학교경주병원, conncect : 확인중(확인중)
# person complete
# ==================================================
# num : 38, info : 여 (한국, '63), path : 확인 중 (확인 중), date : 2.18, hosptl : 경북대학교병원, conncect : 확인중(확인중)
# person complete
# ==================================================
# num : 37, info : 남 (한국, '73), path : 확인 중 (확인 중), date : 2.18, hosptl : 격리 해제, conncect : 확인중(확인중)
# person complete
# ==================================================
# num : 36, info : 여 (한국, '72), path : 확인 중 (확인 중), date : 2.18, hosptl : 대구의료원, conncect : 확인중(확인중)
# person complete
# ==================================================
# num : 35, info : 여 (한국, '94), path : 확인 중 (확인 중), date : 2.18, hosptl : 대구의료원, conncect : 확인중(확인중)
# person complete
# ==================================================
# num : 34, info : 남 (한국, '96), path : 확인 중 (확인 중), date : 2.18, hosptl : 대구의료원, conncect : 확인중(확인중)
# person complete
# ==================================================
# num : 33, info : 여 (한국, '80), path : 확인 중 (확인 중), date : 2.18, hosptl : 대구의료원, conncect : 확인중(확인중)
# person complete
# ==================================================
# page complete
# ====================================================================================================
# num : 52, info : 남 (한국, '96), path : 확인 중 (확인 중), date : 2.19, hosptl : 확인 중, conncect : 확인중(확인중)
# person complete
# ==================================================
# num : 51, info : 여 (한국, '59), path : 31번째 확진자 접촉자 (확인 중), date : 2.19, hosptl : 격리 해제, conncect : 확인중(확인중)
# person complete
# ==================================================
# num : 50, info : 남 (한국, '44), path : 31번째 확진자 접촉자 (확인 중), date : 2.19, hosptl : 영남대학교병원, conncect : 확인중(확인중)
# person complete
# ==================================================
# num : 49, info : 남 (한국, '62), path : 31번째 확진자 접촉자 (확인 중), date : 2.19, hosptl : 경북대학교병원, conncect : 확인중(확인중)
# person complete
# ==================================================
# num : 48, info : 여 (한국, '48), path : 31번째 확진자 접촉자 (확인 중), date : 2.19, hosptl : 칠곡경북대병원, conncect : 확인중(확인중)
# person complete
# ==================================================
# num : 47, info : 여 (한국, '57), path : 31번째 확진자 접촉자 (확인 중), date : 2.19, hosptl : 대구의료원, conncect : 확인중(확인중)
# person complete
# ==================================================
# num : 46, info : 남 (한국, '92), path : 확인 중 (확인 중), date : 2.19, hosptl : 대구의료원, conncect : 확인중(확인중)
# person complete
# ==================================================
# num : 45, info : 여 (한국, '66), path : 확인 중 (확인 중), date : 2.19, hosptl : 대구의료원, conncect : 확인중(확인중)
# person complete
# ==================================================
# num : 44, info : 여 (한국, '74), path : 확인 중 (확인 중), date : 2.19, hosptl : 경북대학교병원, conncect : 확인중(확인중)
# person complete
# ==================================================
# num : 43, info : 여 (한국, '62), path : 확인 중 (확인 중), date : 2.19, hosptl : 계명대학교병원, conncect : 확인중(확인중)
# person complete
# ==================================================
# page complete
# ====================================================================================================
# num : 62, info : 남 (한국, '60), path : 확인 중 (확인 중), date : 2.19, hosptl : 확인 중, conncect : 확인중(확인중)
# person complete
# ==================================================
# num : 61, info : 여 (한국, '62), path : 확인 중 (확인 중), date : 2.19, hosptl : 확인 중, conncect : 확인중(확인중)
# person complete
# ==================================================
# num : 60, info : 여 (한국, '61), path : 확인 중 (확인 중), date : 2.19, hosptl : 확인 중, conncect : 확인중(확인중)
# person complete
# ==================================================
# num : 59, info : 여 (한국, '86), path : 확인 중 (확인 중), date : 2.19, hosptl : 확인 중, conncect : 확인중(확인중)
# person complete
# ==================================================
# num : 58, info : 여 (한국, '94), path : 확인 중 (확인 중), date : 2.19, hosptl : 확인 중, conncect : 확인중(확인중)
# person complete
# ==================================================
# num : 57, info : 남 (한국, '90), path : 확인 중 (확인 중), date : 2.19, hosptl : 확인 중, conncect : 확인중(확인중)
# person complete
# ==================================================
# num : 56, info : 남 (한국, '45), path : 확인 중 (확인 중), date : 2.19, hosptl : 서울의료원, conncect : 확인중(확인중)
# person complete
# ==================================================
# num : 55, info : 남 (한국, '61), path : 확인 중 (확인 중), date : 2.19, hosptl : 포항의료원, conncect : 확인중(확인중)
# person complete
# ==================================================
# num : 54, info : 남 (한국, '63), path : 확인 중 (확인 중), date : 2.19, hosptl : 포항의료원, conncect : 확인중(확인중)
# person complete
# ==================================================
# num : 53, info : 여 (한국, '82), path : 확인 중 (확인 중), date : 2.19, hosptl : 대구의료원, conncect : 확인중(확인중)
# person complete
# ==================================================
# page complete
# ====================================================================================================
# num : 72, info : 여 (한국, '81), path : 확인 중 (확인 중), date : 2.20, hosptl : 확인 중, conncect : 확인중(확인중)
# person complete
# ==================================================
# num : 71, info : 여 (한국, '64), path : 확인 중 (확인 중), date : 2.20, hosptl : 확인 중, conncect : 확인중(확인중)
# person complete
# ==================================================
# num : 70, info : 여 (한국, '72), path : 확인 중 (확인 중), date : 2.20, hosptl : 확인 중, conncect : 확인중(확인중)
# person complete
# ==================================================
# num : 69, info : 남 (한국, '91), path : 확인 중 (확인 중), date : 2.20, hosptl : 확인 중, conncect : 확인중(확인중)
# person complete
# ==================================================
# num : 68, info : 여 (한국, '64), path : 확인 중 (확인 중), date : 2.20, hosptl : 확인 중, conncect : 확인중(확인중)
# person complete
# ==================================================
# num : 67, info : 여 (한국, '90), path : 확인 중 (확인 중), date : 2.20, hosptl : 확인 중, conncect : 확인중(확인중)
# person complete
# ==================================================
# num : 66, info : 남 (한국, '98), path : 확인 중 (확인 중), date : 2.19, hosptl : 확인 중, conncect : 확인중(확인중)
# person complete
# ==================================================
# num : 65, info : 여 (한국, '70), path : 확인 중 (확인 중), date : 2.19, hosptl : 경북대학교병원, conncect : 확인중(확인중)
# person complete
# ==================================================
# num : 64, info : 여 (한국, '61), path : 확인 중 (확인 중), date : 2.19, hosptl : 확인 중, conncect : 확인중(확인중)
# person complete
# ==================================================
# num : 63, info : 여 (한국, '68), path : 확인 중 (확인 중), date : 2.20, hosptl : 확인 중, conncect : 확인중(확인중)
# person complete
# ==================================================
# page complete
# ====================================================================================================
# num : 82, info : 남 (한국, '56), path : 확인 중 (확인 중), date : 2.20, hosptl : 확인 중, conncect : 확인중(확인중)
# person complete
# ==================================================
# num : 81, info : 여 (한국, '55), path : 확인 중 (확인 중), date : 2.20, hosptl : 확인 중, conncect : 확인중(확인중)
# person complete
# ==================================================
# num : 80, info : 여 (한국, '86), path : 확인 중 (확인 중), date : 2.20, hosptl : 확인 중, conncect : 확인중(확인중)
# person complete
# ==================================================
# num : 79, info : 여 (한국, '98), path : 확인 중 (확인 중), date : 2.20, hosptl : 확인 중, conncect : 확인중(확인중)
# person complete
# ==================================================
# num : 78, info : 남 (한국, '65), path : 확인 중 (확인 중), date : 2.20, hosptl : 확인 중, conncect : 확인중(확인중)
# person complete
# ==================================================
# num : 77, info : 여 (한국, '63), path : 확인 중 (확인 중), date : 2.20, hosptl : 확인 중, conncect : 확인중(확인중)
# person complete
# ==================================================
# num : 76, info : 남 (한국, '84), path : 확인 중 (확인 중), date : 2.20, hosptl : 확인 중, conncect : 확인중(확인중)
# person complete
# ==================================================
# num : 75, info : 여 (한국, '97), path : 확인 중 (확인 중), date : 2.20, hosptl : 확인 중, conncect : 확인중(확인중)
# person complete
# ==================================================
# num : 74, info : 남 (한국, '71), path : 확인 중 (확인 중), date : 2.20, hosptl : 확인 중, conncect : 확인중(확인중)
# person complete
# ==================================================
# num : 73, info : 여 (한국, '00), path : 확인 중 (확인 중), date : 2.20, hosptl : 확인 중, conncect : 확인중(확인중)
# person complete
# ==================================================
# page complete
# ====================================================================================================
